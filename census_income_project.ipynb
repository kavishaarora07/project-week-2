# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('census_income')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.apply(lambda x:len(x.unique()))
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# if mean>median, data is right skewed. if there is difference between 75% percentile and max, outliers are present . std is high ,means data is widespread
#
# education number - most people have max level of education
#
# for both capital gain and captain loss we can most data is 0

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
s= (df.dtypes=='object')
cat = list(s[s].index)

print(cat)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
s= (df.dtypes=='int64')
cont=list(s[s].index)

print(cont)
# Out:
# ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
cont.remove('Education_num')

# %%
for i in cont:
    plt.figure(figsize=(20,8))
    sns.distplot(a=df[i],bins=10,kde=False)
    plt.title(i)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['Age'],bins=10)
plt.title("Age")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['Fnlwgt'],bins=10)
plt.title("Fnlwgt")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['Capital_gain'],bins=10)
plt.title("Capital_gain")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['Capital_loss'],bins=10)
plt.title("Capital_loss")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['Hours_per_week'],bins=10)
plt.title("Hours_per_week")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in cat:
    plt.figure(figsize=(20,8))
    df[i].hist(grid=True)
    plt.title(i)
    plt.show()

# %%
plt.figure(figsize=(15,20))
sns.histplot(df['Education'],bins=10)
plt.title("Education")
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.histplot(df['Marital_status'],bins=10)
plt.title("Marital_status")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Occupation'],bins=10)
plt.title("Occupation")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Relationship'],bins=10)
plt.title("Relationship")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Race'],bins=10)
plt.title("Race")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Sex'],bins=10)
plt.title("Sex")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Native_country'],bins=10)
plt.title("Native_country")
plt.show()

# %%
plt.figure(figsize=(30,40))
sns.histplot(df['Income'],bins=10)
plt.title("Income")
plt.show()

# %%
#bivariate analysis

# %%
for i in cont:
    plt.figure(figsize=(15,8))
    ax=sns.stripplot(df['Income'],df[i])
    ax.set(xlabel='Income',ylabel=i)
    plt.title('income vs other continuous attributes')
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in cat[:-1]:
    plt.figure(figsize=(20,8))
    plt.title("Income '%s'"%i)
    sns.countplot(df[i],hue=df['Income'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# private(self employed) are the only ones who have income more than 50k and less 50k earners
#
# hs grad have more income and some college ones too more than 50k
#
# never married have more income

# %%
df['Income'].replace(' <=50k',0,inplace=True)
df['Income'].replace(' >50k',1,inplace=True)

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.corr(),annot=True)
plt.title('correlation matrix')
plt.show()

# %% [markdown]
# eduaction seens to be most correlated with income(0.34) apart from that age, hours_per_week and capital_gain are very much correlated with income at 0.23,0,23 and 0.22
#
# final weight seems to be least correlated with income

# %%
#outliers

# %%
for i in cont:
    plt.figure(figsize=(20,15))
    df[i].plot.box()

# %%
df.skew()
# Out:
# C:\Users\Kavisha\AppData\Local\Temp\ipykernel_21144\1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Age                0.558738
# Fnlwgt             1.446972
# Education_num     -0.311630
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# dtype: float64

# %%
cont.remove('Age')
cont.remove('Hours_per_week')

# %%
df1=df

# %%
from sklearn.preprocessing import power_transform
df1[cont]=power_transform(df[cont],method='yeo-johnson')
df1=pd.DataFrame(df1,columns=df.columns)

# %%
df1.skew()
# Out:
# C:\Users\Kavisha\AppData\Local\Temp\ipykernel_21144\149261804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()
# Age               0.558738
# Fnlwgt            0.016914
# Education_num    -0.311630
# Capital_gain      3.016951
# Capital_loss      4.299511
# Hours_per_week    0.227636
# dtype: float64

# %%
s= (df.dtypes == 'object')
cols = list(s[s].index)

print("categorical column")
print(cols)
# Out:
# categorical column
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
cols.remove('Education')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in cols:
    df1[col]=le.fit_transform(df1[col])

# %%
df1=df1.drop('Education',axis=1)

# %%
#dropping education as education_num is already present

# %%
x=df1.drop('Income',axis=1)
y=df1['Income']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
x
# Out:
#        Age  Workclass    Fnlwgt  Education_num  Marital_status  Occupation  \
# 0       50          6 -1.089889             13               2           4
# 1       38          4  0.398743              9               0           6
# 2       53          4  0.562540              7               2           6
# 3       28          4  1.340398             13               2          10
# 4       37          4  0.957182             14               2           4
# ...    ...        ...       ...            ...             ...         ...
# 32555   27          4  0.746749             12               2          13
# 32556   40          4 -0.193298              9               2           7
# 32557   58          4 -0.219755              9               6           1
# 32558   22          4  0.271668              9               4           1
# 32559   52          5  0.982165              9               2           4
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=448)

# %%
lr = LogisticRegression()
gb= GaussianNB()
dtc= DecisionTreeClassifier()
svc=SVC()
rf=RandomForestClassifier()
et=ExtraTreesClassifier()
ada=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
models=[lr,gb,dtc,svc,rf,et,ada,gbc]
for i in models:
    print(i)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
# Out:
# LogisticRegression()
# 0.8272932022932022
# [[7029  485]
#  [1202 1052]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      7514
#            1       0.68      0.47      0.55      2254
#
#     accuracy                           0.83      9768
#    macro avg       0.77      0.70      0.72      9768
# weighted avg       0.81      0.83      0.81      9768
#
# GaussianNB()
# 0.8156224406224406
# [[6655  859]
#  [ 942 1312]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      7514
#            1       0.60      0.58      0.59      2254
#
#     accuracy                           0.82      9768
#    macro avg       0.74      0.73      0.74      9768
# weighted avg       0.81      0.82      0.81      9768
#
# DecisionTreeClassifier()
# 0.8050778050778051
# [[6496 1018]
#  [ 886 1368]]
#               precision    recall  f1-score   support
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
for i in models:
    print('accuracy score of',i,'is',accuracy_score(y_test,pred))
    cvs=cross_val_score(i,x,y,cv=5)
    print('cross validation score for',i,'model is:',cvs.mean())
    print(' ')
# Out:
# accuracy score of LogisticRegression() is 0.8676289926289926
# cross validation score for LogisticRegression() model is: 0.8140049140049141
#
# accuracy score of GaussianNB() is 0.8676289926289926
# cross validation score for GaussianNB() model is: 0.8102272727272728
#
# accuracy score of DecisionTreeClassifier() is 0.8676289926289926
# cross validation score for DecisionTreeClassifier() model is: 0.8018427518427519
#
# accuracy score of SVC() is 0.8676289926289926
# cross validation score for SVC() model is: 0.8196867321867322
#
# accuracy score of RandomForestClassifier() is 0.8676289926289926
# cross validation score for RandomForestClassifier() model is: 0.8522113022113021
#
# accuracy score of ExtraTreesClassifier() is 0.8676289926289926
# cross validation score for ExtraTreesClassifier() model is: 0.8439496314496315
#
# accuracy score of AdaBoostClassifier() is 0.8676289926289926
# cross validation score for AdaBoostClassifier() model is: 0.8568796068796068
#
# ...

# %%
#gradient boost is the best

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={"learning_rate":[0.01,0.05,0.1,0.2,0.3,0.5],
       "n_estimators":[5,50,100,200,300,400],
        "max_depth":[3,4,5,6,8]
       }

# %%
GCV=GridSearchCV(gbc,params,cv=5,scoring='accuracy',n_jobs=-1)

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_estimator_

# %%
GCV.best_params_

# %%
pred=GCV.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,pred)

# %%
print("accuracy score",round(accuracy_score(y_test,pred)*100,2))

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
sns.heatmap(confusion_matrix(y_test,pred),annot=True,fmt='d')

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve

# %%
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC PLOT")
plt.show
